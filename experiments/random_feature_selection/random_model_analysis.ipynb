# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import xgboost
import plotly.express as px
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error, mean_squared_error, precision_score, recall_score
import warnings
from plotly.subplots import make_subplots
import plotly.graph_objects as go
warnings.filterwarnings('ignore')

# %%
datasets = ["BZR", "NCI1", "MUTAG", "PROTEINS", "IMDB"]
fixed_cols = ["graph_id", "graph_label", "dataset", "feat_len"]

embeddings = pd.read_csv("./data/embeddings.csv")
feat_importance = pd.read_csv("./data/feat_importance.csv")

# %%
emb_data = pd.DataFrame()
for dataset in datasets:
    df = embeddings[embeddings["dataset"] == dataset].copy(deep=True)
    dfm = pd.DataFrame()
    for feat_len in df["feat_len"].unique().tolist():
        tmp = df[df["feat_len"] == feat_len].copy(deep=True)
        col_rename = {}
        for col in tmp.columns:
            if col not in fixed_cols:
                col_rename[col] = col +"_"+ str(feat_len-1)
        tmp.rename(columns=col_rename, inplace=True)
        tmp = tmp.drop('feat_len', axis=1)
        tmp = tmp.drop('dataset', axis=1)
        if dfm.empty:
            dfm = tmp.copy(deep=True)
        else:
            dfm = dfm.merge(tmp, on=["graph_id", "graph_label"])
    dfm["dataset"] = dataset        
    if emb_data.empty:
        emb_data = dfm.copy(deep=True)
    else:
        emb_data = pd.concat([emb_data, dfm])

# %%
emb_data.head(2)
# Out:
#    graph_id  graph_label  basic_expansion_0  self_walk_0  page_rank_0  \
# 0         0           -1       1.946408e-09    -0.021841     0.216180
# 1         1           -1       4.386578e-09    -0.044379     0.097098
#
#    degree_centrality_0  closeness_centrality_0  load_centrality_0  \
# 0             0.202306                0.289911           0.026240
# 1             0.079057                0.198728          -0.028358
#
#    eigenvector_centrality_0    lsme_0  ...    lsme_2  basic_expansion_3  \
# 0                  0.199050 -0.070985  ... -0.009453          -0.210577
# 1                  0.110442  0.012324  ... -0.098743           0.004913
#
#    self_walk_3  page_rank_3  degree_centrality_3  closeness_centrality_3  \
# 0    -0.203792     0.308946             0.291383               -0.376381
# 1    -0.210504     0.228915             0.200574               -0.279066
#
#    load_centrality_3  eigenvector_centrality_3    lsme_3  dataset
# 0          -0.196976                 -0.286197 -0.149529      BZR
# 1          -0.166603                 -0.232289  0.101702      BZR
#
# [2 rows x 35 columns]

# %%
def build_models(data, dataset, feat_imp):

    feat_imp_df = feat_imp[feat_imp["dataset"] == dataset].copy(deep=True)
    data_df = data[data["dataset"] == dataset].copy(deep=True)

    raw_classes = data_df["graph_label"].unique().tolist()
    class_map = {}
    class_remap = 0
    for class_val in raw_classes:
        class_map[class_val] = class_remap
        class_remap += 1
    data_df["graph_label"] = data_df["graph_label"].apply(lambda x: class_map[x])
    
    feat_imp_list = feat_imp_df["features"].tolist()

    selected_feat = []
    feat_list = []
    accuracy_mean = []
    accuracy_std = []
    for feat in feat_imp_list:
        acc = []
        for i in range(30):
            selected_feat.append(feat)
            selected_feat = list(set(selected_feat))
    
            X = data_df[selected_feat].copy(deep=True)
            y = data_df[["graph_label"]].copy(deep=True)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
        
            scaler = StandardScaler()
            scaler.fit(X_train)
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.fit_transform(X_test)
    
            # Random Forrest
            model = RandomForestClassifier()
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test).flatten()
            accuracy = accuracy_score(y_test, y_pred)
    
            acc.append(accuracy)
            
        feat_list.append(feat)
        accuracy_mean.append(np.mean(np.array(acc)))
        accuracy_std.append(np.std(np.array(acc)))

    results = pd.DataFrame()
    results["selected_features"] = feat_list
    results["accuracy_contribution"] = accuracy_mean
    results["accuracy_contribution_std"] = accuracy_std
    return results

# %%
result = pd.DataFrame()
for i in tqdm(range(50), desc="runs"):
    DATASET = "NCI1"
    feat_importance["dataset"] = DATASET
    feat_importance = feat_importance.sample(frac=1.0)
    df = build_models(emb_data, DATASET, feat_importance)
    df["run"] = i
    if result.empty:
        result = df.copy(deep=True)
    else:
        result = pd.concat([result, df])

# df.to_csv("./results/"+DATASET+".csv", index=False)
# Out:
# runs: 100%|█████████████████████████████████████████████████████████████████████████| 50/50 [8:21:26<00:00, 601.74s/it]

# %%
result.to_csv("./results/random_samples.csv", index=False)

# %%
result.head(2)
# Out:
#    selected_features  accuracy_contribution  accuracy_contribution_std  run
# 0  load_centrality_2               0.545904                   0.015590    0
# 1  load_centrality_3               0.609895                   0.018723    0

# %%
result.shape
# Out:
# (1600, 4)

# %%
result_cp = result.copy(deep=True)

# %%
result_cp["feat_index"] = [i for i in range(len(result[result["run"] == 0]))] * len(result["run"].unique())

# %%
result_cp.head(40)
# Out:
#            selected_features  accuracy_contribution  \
# 0          load_centrality_2               0.545904
# 1          load_centrality_3               0.609895
# 2                page_rank_2               0.662368
# 3     closeness_centrality_0               0.675831
# 4   eigenvector_centrality_1               0.679805
# 5        degree_centrality_1               0.681076
# 6          basic_expansion_1               0.697161
# 7                     lsme_3               0.698729
# 8          basic_expansion_3               0.704785
# 9                     lsme_2               0.704380
# 10               self_walk_1               0.705001
# 11         load_centrality_1               0.711165
# 12               page_rank_0               0.713842
# 13               page_rank_3               0.706488
# 14               self_walk_3               0.716167
# 15    closeness_centrality_2               0.721519
# 16         basic_expansion_2               0.723655
# 17  eigenvector_centrality_0               0.725656
# 18         basic_expansion_0               0.726791
# 19       degree_centrality_3               0.725683
# 20    closeness_centrality_3               0.724790
# 21    closeness_centrality_1               0.722655
# 22                    lsme_1               0.725277
# 23               page_rank_1               0.721573
# 24         load_centrality_0               0.726872
# 25       degree_centrality_0               0.725061
# 26  eigenvector_centrality_3               0.730738
# 27       degree_centrality_2               0.728494
# 28               self_walk_0               0.729792
# 29                    lsme_0               0.731198
# 30               self_walk_2               0.727088
# 31  eigenvector_centrality_2               0.732820
# 0                self_walk_2               0.529008
# 1                page_rank_2               0.613706
# 2                page_rank_3               0.636929
# 3          basic_expansion_2               0.666342
# 4   eigenvector_centrality_2               0.692620
# 5          basic_expansion_1               0.709732
# 6     closeness_centrality_1               0.710111
# 7        degree_centrality_1               0.709408
#
#     accuracy_contribution_std  run  feat_index
# 0                    0.015590    0           0
# 1                    0.018723    0           1
# 2                    0.010346    0           2
# 3                    0.011293    0           3
# 4                    0.009688    0           4
# 5                    0.009671    0           5
# 6                    0.014008    0           6
# 7                    0.011810    0           7
# 8                    0.013860    0           8
# 9                    0.009952    0           9
# 10                   0.011358    0          10
# 11                   0.011456    0          11
# 12                   0.010806    0          12
# 13                   0.011349    0          13
# 14                   0.013713    0          14
# 15                   0.011127    0          15
# 16                   0.010997    0          16
# 17                   0.011680    0          17
# 18                   0.012075    0          18
# 19                   0.011167    0          19
# 20                   0.010523    0          20
# 21                   0.009976    0          21
# 22                   0.013428    0          22
# 23                   0.010429    0          23
# 24                   0.011033    0          24
# 25                   0.011909    0          25
# 26                   0.012337    0          26
# 27                   0.011882    0          27
# 28                   0.011734    0          28
# 29                   0.010524    0          29
# 30                   0.014661    0          30
# 31                   0.009518    0          31
# 0                    0.018049    1           0
# 1                    0.012063    1           1
# 2                    0.016425    1           2
# 3                    0.015518    1           3
# 4                    0.015533    1           4
# 5                    0.011900    1           5
# 6                    0.014025    1           6
# 7                    0.012514    1           7

# %%
# result_cp2 = pd.DataFrame(result_cp.groupby(by=["feat_index"])["accuracy_contribution"].min()).reset_index()
# result_cp3 = pd.DataFrame(result_cp.groupby(by=["feat_index"])["accuracy_contribution_std"].max()).reset_index()
# dfdf = result_cp2.merge(result_cp3, on="feat_index")
# dfdf

# %%
feat_index_list = []
accuracy_contribution_list = []
accuracy_contribution_std_list = []
for feat_index in result_cp["feat_index"].unique().tolist():
    tmp = result_cp[result_cp["feat_index"] == feat_index]
    feat_index_list.append(feat_index)
    accuracy_contribution_list.append(tmp["accuracy_contribution"].min())
    accuracy_contribution_std_list.append(tmp["accuracy_contribution"].max() - tmp["accuracy_contribution"].min())

dfdf = pd.DataFrame()
dfdf["feat_index"] = feat_index_list
dfdf["accuracy_contribution"] = accuracy_contribution_list
dfdf["accuracy_contribution_std"] = accuracy_contribution_std_list

# %%
dfdf.to_csv("./results/NCI1.csv", index=False)

# %%
dfdf
# Out:
#     feat_index  accuracy_contribution  accuracy_contribution_std
# 0            0               0.501244                   0.081941
# 1            1               0.530792                   0.087186
# 2            2               0.563368                   0.104353
# 3            3               0.604298                   0.078291
# 4            4               0.616464                   0.079778
# 5            5               0.625926                   0.083806
# 6            6               0.637497                   0.072803
# 7            7               0.655664                   0.063152
# 8            8               0.661882                   0.059611
# 9            9               0.667234                   0.054880
# 10          10               0.671127                   0.056961
# 11          11               0.672101                   0.058854
# 12          12               0.680130                   0.047689
# 13          13               0.678562                   0.051825
# 14          14               0.679859                   0.050716
# 15          15               0.693106                   0.037253
# 16          16               0.701162                   0.033117
# 17          17               0.697080                   0.033631
# 18          18               0.700054                   0.030684
# 19          19               0.700973                   0.032901
# 20          20               0.697486                   0.037659
# 21          21               0.701595                   0.034928
# 22          22               0.703460                   0.035442
# 23          23               0.699649                   0.038254
# 24          24               0.710057                   0.027602
# 25          25               0.713625                   0.020303
# 26          26               0.716058                   0.019384
# 27          27               0.719492                   0.019384
# 28          28               0.723412                   0.012733
# 29          29               0.725602                   0.010760
# 30          30               0.723601                   0.010679
# 31          31               0.726548                   0.008029
