# %%
import pandas as pd

df = pd.read_parquet('results.parquet')

# %%
df
# Out:
#           data outlier_mode   model     score  score_std  score_max  \
# 0     inj_cora          any      IF  0.710054   0.012521   0.719283
# 1     inj_cora          any     LOF  0.561047   0.075554   0.700460
# 2     inj_cora          any  cosine  0.510286        NaN        NaN
# 3     inj_cora          any     knn  0.605072        NaN        NaN
# 4     inj_cora          any    lgbm  0.500000        NaN        NaN
# ..         ...          ...     ...       ...        ...        ...
# 57    inj_cora   contextual  cosine  0.499810        NaN        NaN
# 58    inj_cora   contextual     knn  0.577055        NaN        NaN
# 59    inj_cora   contextual    lgbm  0.500000        NaN        NaN
# 60  inj_amazon          any      IF  0.732875   0.003589   0.736147
# 61  inj_amazon          any     LOF  0.529805   0.022059   0.561919
#
#     hide_frac_0  hide_frac_1 comment
# 0          1.00         1.00
# 1          1.00         1.00
# 2          0.95         0.95
# ...

# %%
q = df[(df['data'] == 'abcdo_data_1000_200_0.1') & (df['model'] == 'cosine')]
q
# Out:
#                        data outlier_mode   model     score  score_std  \
# 22  abcdo_data_1000_200_0.1          any  cosine  0.717500        NaN
# 25  abcdo_data_1000_200_0.1          any  cosine  0.810000        NaN
# 28  abcdo_data_1000_200_0.1          any  cosine  0.793750        NaN
# 31  abcdo_data_1000_200_0.1          any  cosine  0.848750        NaN
# 34  abcdo_data_1000_200_0.1          any  cosine  0.835625        NaN
# 37  abcdo_data_1000_200_0.1          any  cosine  0.853750        NaN
#
#     score_max  hide_frac_0  hide_frac_1 comment
# 22        NaN         0.95         0.95
# 25        NaN         0.90         0.90
# 28        NaN         0.80         0.80
# 31        NaN         0.50         0.50
# 34        NaN         0.25         0.25
# 37        NaN         0.10         0.10

# %%
import matplotlib.pyplot as plt

plt.plot(1-q['hide_frac_1'],q['score'])
